# %% [markdown]
# # Dinesh - 8295780747
# #### dinstar311@gmail.com
#
#
#
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("Pest Count and weather data _North Zone.xlsx")

# %%
data
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3      Input Parameters  \
# 0          NaN        NaN        NaN        NaN  Min Temp (Deg. Cel.)
# 1    Location        Year      Week       Month                  Tmin
# 2     Faridkot       2010         22        May                  31.9
# 3     Faridkot       2010         23       June                  28.1
# 4     Faridkot       2010         24       June                  31.2
# ..         ...        ...        ...        ...                   ...
# 367      Hisar       2016         36     August                  23.5
# 368      Hisar       2016         37  September                  23.6
# 369      Hisar       2016         38  September                  25.1
# 370      Hisar       2016         39  September                  24.4
# 371      Hisar       2016         40  September                  24.5
#
#                Unnamed: 5            Unnamed: 6        Unnamed: 7  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
data.rename(columns=data.iloc[1],inplace=True)

# %%
data
# Out:
#      Location   Year  Week       Month                  Tmin  \
# 0          NaN   NaN    NaN        NaN  Min Temp (Deg. Cel.)
# 1    Location   Year  Week       Month                  Tmin
# 2     Faridkot  2010     22        May                  31.9
# 3     Faridkot  2010     23       June                  28.1
# 4     Faridkot  2010     24       June                  31.2
# ..         ...   ...    ...        ...                   ...
# 367      Hisar  2016     36     August                  23.5
# 368      Hisar  2016     37  September                  23.6
# 369      Hisar  2016     38  September                  25.1
# 370      Hisar  2016     39  September                  24.4
# 371      Hisar  2016     40  September                  24.5
#
#                      Tmax                  Tavg             Rhmin  \
# 0    Max Temp (Deg. Cel.)  Avg Temp (Deg. Cel.)  Min Humidity (%)
# 1                    Tmax                  Tavg             Rhmin
# ...

# %%
data.drop([0,1],axis=0,inplace=True)

# %%
data
# Out:
#     Location   Year Week       Month  Tmin  Tmax   Tavg Rhmin RHmax RH avg  \
# 2    Faridkot  2010    22        May  31.9    35     34  34.3    56   45.2
# 3    Faridkot  2010    23       June  28.1    36     32  27.9    55   41.3
# 4    Faridkot  2010    24       June  31.2    40     36  21.9    48   34.8
# 5    Faridkot  2010    25       June  29.9    37     34  40.6    68   54.2
# 6    Faridkot  2010    26       June  28.9    32     30  65.3    72   68.6
# ..        ...   ...   ...        ...   ...   ...    ...   ...   ...    ...
# 367     Hisar  2016    36     August  23.5  34.6  29.05    58    86     72
# 368     Hisar  2016    37  September  23.6  35.7  29.65    52    85   68.5
# 369     Hisar  2016    38  September  25.1    36  30.55    54    87   70.5
# 370     Hisar  2016    39  September  24.4  35.4   29.9    49    85     67
# 371     Hisar  2016    40  September  24.5    35  29.75    56    91   73.5
#
#       RF Pest Count (Dependent Variable)
# ...

# %%
data.isnull().sum()
# Out:
# Location                             0
# Year                                 0
# Week                                 0
# Month                                0
# Tmin                                 0
# Tmax                                 0
# Tavg                                 0
# Rhmin                               60
# RHmax                               60
# RH avg                               0
# RF                                 344
# Pest Count (Dependent Variable)      0
# dtype: int64

# %%
data.drop(['Rhmin','RHmax','RF'],axis=1,inplace=True)

# %%
data.head(10)
# Out:
#    Location   Year Week  Month  Tmin Tmax Tavg RH avg  \
# 2   Faridkot  2010    22   May  31.9   35   34   45.2
# 3   Faridkot  2010    23  June  28.1   36   32   41.3
# 4   Faridkot  2010    24  June  31.2   40   36   34.8
# 5   Faridkot  2010    25  June  29.9   37   34   54.2
# 6   Faridkot  2010    26  June  28.9   32   30   68.6
# 7   Faridkot  2010    27  July  28.3   34   31   74.5
# 8   Faridkot  2010    28  July  29.7   34   32   81.6
# 9   Faridkot  2010    29  July  27.9   31   29   87.7
# 10  Faridkot  2010    30  July  28.1   33   30   84.4
# 11  Faridkot  2010    31  July  28.8   33   31    757
#
#    Pest Count (Dependent Variable)
# 2                              0.1
# 3                              1.1
# 4                              2.7
# 5                              7.4
# 6                             12.9
# 7                             10.9
# 8                               13
# 9                             17.2
# 10                            23.2
# ...

# %%
data
# Out:
#     Location   Year Week       Month  Tmin  Tmax   Tavg RH avg  \
# 2    Faridkot  2010    22        May  31.9    35     34   45.2
# 3    Faridkot  2010    23       June  28.1    36     32   41.3
# 4    Faridkot  2010    24       June  31.2    40     36   34.8
# 5    Faridkot  2010    25       June  29.9    37     34   54.2
# 6    Faridkot  2010    26       June  28.9    32     30   68.6
# ..        ...   ...   ...        ...   ...   ...    ...    ...
# 367     Hisar  2016    36     August  23.5  34.6  29.05     72
# 368     Hisar  2016    37  September  23.6  35.7  29.65   68.5
# 369     Hisar  2016    38  September  25.1    36  30.55   70.5
# 370     Hisar  2016    39  September  24.4  35.4   29.9     67
# 371     Hisar  2016    40  September  24.5    35  29.75   73.5
#
#     Pest Count (Dependent Variable)
# 2                               0.1
# 3                               1.1
# 4                               2.7
# 5                               7.4
# ...

# %%
data['Year'].value_counts()
# Out:
# 2011    73
# 2010    65
# 2012    64
# 2014    55
# 2015    51
# 2016    39
# 2013    23
# Name: Year, dtype: int64

# %%
data.columns
# Out:
# Index(['Location ', 'Year', 'Week ', 'Month', 'Tmin', 'Tmax', 'Tavg', 'RH avg',
#        'Pest Count (Dependent Variable)'],
#       dtype='object')

# %%
data = data.rename(columns={'Location ':'Location','Week ': 'Week'})

# %%
data.columns
# Out:
# Index(['Location', 'Year', 'Week', 'Month', 'Tmin', 'Tmax', 'Tavg', 'RH avg',
#        'Pest Count (Dependent Variable)'],
#       dtype='object')

# %%
data['Location'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 2      Faridkot
# 3      Faridkot
# 4      Faridkot
# 5      Faridkot
# 6      Faridkot
#          ...
# 367       Hisar
# 368       Hisar
# 369       Hisar
# 370       Hisar
# 371       Hisar
# Name: Location, Length: 370, dtype: object>

# %%
data['Location'].value_counts()
# Out:
# Faridkot    161
# Hisar       125
# Sirsa        84
# Name: Location, dtype: int64

# %%
data
# Out:
#      Location  Year Week      Month  Tmin  Tmax   Tavg RH avg  \
# 2    Faridkot  2010   22        May  31.9    35     34   45.2
# 3    Faridkot  2010   23       June  28.1    36     32   41.3
# 4    Faridkot  2010   24       June  31.2    40     36   34.8
# 5    Faridkot  2010   25       June  29.9    37     34   54.2
# 6    Faridkot  2010   26       June  28.9    32     30   68.6
# ..        ...   ...  ...        ...   ...   ...    ...    ...
# 367     Hisar  2016   36     August  23.5  34.6  29.05     72
# 368     Hisar  2016   37  September  23.6  35.7  29.65   68.5
# 369     Hisar  2016   38  September  25.1    36  30.55   70.5
# 370     Hisar  2016   39  September  24.4  35.4   29.9     67
# 371     Hisar  2016   40  September  24.5    35  29.75   73.5
#
#     Pest Count (Dependent Variable)
# 2                               0.1
# 3                               1.1
# 4                               2.7
# 5                               7.4
# ...

# %%
Hisar_data=data[data['Location']=='Hisar']

# %%
Faridkot_data=data[data['Location']=='Faridkot']

# %%
Sirsa_data=data[data['Location']=='Sirsa']

# %%
Faridkot_data
# Out:
#      Location  Year Week      Month  Tmin  Tmax   Tavg RH avg  \
# 2    Faridkot  2010   22        May  31.9    35     34   45.2
# 3    Faridkot  2010   23       June  28.1    36     32   41.3
# 4    Faridkot  2010   24       June  31.2    40     36   34.8
# 5    Faridkot  2010   25       June  29.9    37     34   54.2
# 6    Faridkot  2010   26       June  28.9    32     30   68.6
# ..        ...   ...  ...        ...   ...   ...    ...    ...
# 348  Faridkot  2016   40  September  24.6  35.2   29.9     71
# 349  Faridkot  2016   41    October  19.9  34.7   27.3     60
# 350  Faridkot  2016   42    October  15.6  34.5  25.05   57.4
# 351  Faridkot  2016   43    October  16.7  32.7   24.7   60.7
# 352  Faridkot  2016   44    October  19.2  30.2   24.7   65.4
#
#     Pest Count (Dependent Variable)
# 2                               0.1
# 3                               1.1
# 4                               2.7
# 5                               7.4
# ...

# %% [markdown]
# # Year or month with high/low pest counts

# %%
fg=Faridkot_data.groupby(['Year','Month'])

# %%
max_fd=fg.agg({'Pest Count (Dependent Variable)' : max})
min_fd=fg.agg({'Pest Count (Dependent Variable)' : min})

# %%
max_fd
# Out:
#                 Pest Count (Dependent Variable)
# Year Month
# 2010 August                               12.60
#      July                                 23.20
#      June                                 12.90
#      May                                   0.10
#      November                              0.50
#      October                               5.60
#      September                             9.90
# 2011 August                                8.30
#      December                              0.00
#      July                                 15.50
#      June                                  2.90
#      May                                   0.20
#      November                              2.00
#      October                               5.90
#      September                             5.20
# 2012 August                                6.70
#      July                                 13.20
#      June                                  4.50
# ...

# %%
min_fd
# Out:
#                 Pest Count (Dependent Variable)
# Year Month
# 2010 August                                5.40
#      July                                 10.90
#      June                                  1.10
#      May                                   0.10
#      November                              0.20
#      October                               1.70
#      September                             4.70
# 2011 August                                3.20
#      December                              0.00
#      July                                  0.90
#      June                                  0.20
#      May                                   0.20
#      November                              0.00
#      October                               2.10
#      September                             2.70
# 2012 August                                2.00
#      July                                  5.20
#      June                                  0.50
# ...

# %% [markdown]
# # High/low pest count with location year & month combindly

# %%
grp= data.groupby(['Location','Year','Month'])

# %%
max_grp= grp.agg({'Pest Count (Dependent Variable)' : max})

# %%
max_grp
# Out:
#                          Pest Count (Dependent Variable)
# Location Year Month
# Faridkot 2010 August                               12.60
#               July                                 23.20
#               June                                 12.90
#               May                                   0.10
#               November                              0.50
# ...                                                  ...
# Sirsa    2014 June                                  5.00
#               September                            49.30
#          2015 August                               70.00
#               July                                 27.75
#               June                                  6.25
#
# [102 rows x 1 columns]

# %%
min_grp= grp.agg({'Pest Count (Dependent Variable)' : min})

# %%
min_grp
# Out:
#                          Pest Count (Dependent Variable)
# Location Year Month
# Faridkot 2010 August                                5.40
#               July                                 10.90
#               June                                  1.10
#               May                                   0.10
#               November                              0.20
# ...                                                  ...
# Sirsa    2014 June                                  0.00
#               September                            12.50
#          2015 August                               25.75
#               July                                 14.50
#               June                                  1.75
#
# [102 rows x 1 columns]

# %% [markdown]
# # High/low pest count with location only

# %%
lc=data.groupby(['Location'])

# %%
lc_max = lc.agg({'Pest Count (Dependent Variable)' : max})

# %%
lc_max
# Out:
#           Pest Count (Dependent Variable)
# Location
# Faridkot                             61.8
# Hisar                               322.0
# Sirsa                                70.0

# %%
lc_min = lc.agg({'Pest Count (Dependent Variable)' : min})

# %%
lc_min
# Out:
#           Pest Count (Dependent Variable)
# Location
# Faridkot                                0
# Hisar                                   0
# Sirsa                                   0

# %% [markdown]
# # Merge the table to get min & max pest count value with the help of location year & month

# %%
new= pd.merge(max_grp,data,how='left',left_on=['Location','Year','Month'],right_on=['Location','Year','Month'])

# %%
new
# Out:
#      Location  Year   Month  Pest Count (Dependent Variable)_x Week  Tmin  \
# 0    Faridkot  2010  August                              12.60   32  27.8
# 1    Faridkot  2010  August                              12.60   33  27.9
# 2    Faridkot  2010  August                              12.60   34    27
# 3    Faridkot  2010  August                              12.60   35  27.4
# 4    Faridkot  2010    July                              23.20   27  28.3
# ..        ...   ...     ...                                ...  ...   ...
# 365     Sirsa  2015    July                              27.75   30    26
# 366     Sirsa  2015    July                              27.75   31  25.5
# 367     Sirsa  2015    June                               6.25   24  26.5
# 368     Sirsa  2015    June                               6.25   25  27.8
# 369     Sirsa  2015    June                               6.25   26    27
#
#      Tmax   Tavg RH avg Pest Count (Dependent Variable)_y
# ...

# %%
final= pd.merge(min_grp,new,how='left',left_on=['Location','Year','Month'],right_on=['Location','Year','Month'])

# %%
final
# Out:
#      Location  Year   Month  Pest Count (Dependent Variable)  \
# 0    Faridkot  2010  August                             5.40
# 1    Faridkot  2010  August                             5.40
# 2    Faridkot  2010  August                             5.40
# 3    Faridkot  2010  August                             5.40
# 4    Faridkot  2010    July                            10.90
# ..        ...   ...     ...                              ...
# 365     Sirsa  2015    July                            14.50
# 366     Sirsa  2015    July                            14.50
# 367     Sirsa  2015    June                             1.75
# 368     Sirsa  2015    June                             1.75
# 369     Sirsa  2015    June                             1.75
#
#      Pest Count (Dependent Variable)_x Week  Tmin  Tmax   Tavg RH avg  \
# 0                                12.60   32  27.8    33     31   85.1
# 1                                12.60   33  27.9    33     31   87.7
# ...

# %%
final.rename(columns={'Pest Count (Dependent Variable)': 'min Pest Count','Pest Count (Dependent Variable)_x' : 'max Pest Count','Pest Count (Dependent Variable)_y' : 'Pest Count'},inplace=True)

# %%
final
# Out:
#      Location  Year   Month  min Pest Count  max Pest Count Week  Tmin  Tmax  \
# 0    Faridkot  2010  August            5.40           12.60   32  27.8    33
# 1    Faridkot  2010  August            5.40           12.60   33  27.9    33
# 2    Faridkot  2010  August            5.40           12.60   34    27    33
# 3    Faridkot  2010  August            5.40           12.60   35  27.4    33
# 4    Faridkot  2010    July           10.90           23.20   27  28.3    34
# ..        ...   ...     ...             ...             ...  ...   ...   ...
# 365     Sirsa  2015    July           14.50           27.75   30    26  33.8
# 366     Sirsa  2015    July           14.50           27.75   31  25.5  31.8
# 367     Sirsa  2015    June            1.75            6.25   24  26.5  38.2
# 368     Sirsa  2015    June            1.75            6.25   25  27.8  39.3
# 369     Sirsa  2015    June            1.75            6.25   26    27  38.9
#
#       Tavg RH avg Pest Count
# ...

# %% [markdown]
# # Data Visualization

# %%
sns.distplot(final['Pest Count'])
# Out:
# C:\Users\SqyUser.SY-LP-GGN-511\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Pest Count', ylabel='Density'>

# %%
sns.countplot(x='Location',data=final,hue='Year')
# Out:
# <AxesSubplot:xlabel='Location', ylabel='count'>

# %%
sns.countplot(x='Location',data=final,hue='Month')
# Out:
# <AxesSubplot:xlabel='Location', ylabel='count'>

# %%
plt.scatter(final['Location'],final['Pest Count'])

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x="Year", y="Pest Count", data=final, hue="Location")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Pest Count'>

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x="Month", y="Pest Count", data=final, hue="Location")
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Pest Count'>

# %%
final.dtypes
# Out:
# Location             int64
# Year                 int64
# Month               object
# min Pest Count     float64
# max Pest Count     float64
# Week                object
# Tmin                object
# Tmax                object
# Tavg               float64
# RH avg             float64
# Pest Count         float64
# Pest_label        category
# dtype: object

# %% [markdown]
# # Convert the data types object into integers for model creation

# %%
final['Tavg']=final['Tavg'].astype(float)

# %%
final['RH avg']=final['RH avg'].astype(float)

# %%
final['Pest Count']=final['Pest Count'].astype(float)

# %%
final.dtypes
# Out:
# Location           object
# Year                int64
# Month              object
# min Pest Count    float64
# max Pest Count    float64
# Week               object
# Tmin               object
# Tmax               object
# Tavg              float64
# RH avg            float64
# Pest Count        float64
# dtype: object

# %%
sns.heatmap(final.corr())
# Out:
# <AxesSubplot:>

# %%
final.corr()
# Out:
#                     Year  min Pest Count  max Pest Count      Tavg    RH avg  \
# Year            1.000000        0.188292        0.305837  0.254400 -0.028621
# min Pest Count  0.188292        1.000000        0.900386  0.082065  0.066253
# max Pest Count  0.305837        0.900386        1.000000  0.147032  0.068651
# Tavg            0.254400        0.082065        0.147032  1.000000  0.022953
# RH avg         -0.028621        0.066253        0.068651  0.022953  1.000000
# Pest Count      0.244350        0.931768        0.947162  0.115671  0.067925
#
#                 Pest Count
# Year              0.244350
# min Pest Count    0.931768
# max Pest Count    0.947162
# Tavg              0.115671
# RH avg            0.067925
# Pest Count        1.000000

# %% [markdown]
# # Make pest count values into categorical like low, medium ,high & very high

# %%
final['Pest Count'].max()
# Out:
# 322.0

# %%
final['Pest Count'].min()
# Out:
# 0.0

# %% [markdown]
# # As we find that pest max is 322 & pest min is 0 & we have to divide it into 4 categories like 0-80 as low, 80-160 as medium, 160-240 as high & 240-330 as very high.

# %%
label=['low','medium','high','very high']
category=[0.,80.,160.,240.,330.]
final['Pest_label']=pd.cut(final['Pest Count'],labels=label,bins=category)

# %%
final
# Out:
#      Location  Year   Month  min Pest Count  max Pest Count Week  Tmin  Tmax  \
# 0    Faridkot  2010  August            5.40           12.60   32  27.8    33
# 1    Faridkot  2010  August            5.40           12.60   33  27.9    33
# 2    Faridkot  2010  August            5.40           12.60   34    27    33
# 3    Faridkot  2010  August            5.40           12.60   35  27.4    33
# 4    Faridkot  2010    July           10.90           23.20   27  28.3    34
# ..        ...   ...     ...             ...             ...  ...   ...   ...
# 365     Sirsa  2015    July           14.50           27.75   30    26  33.8
# 366     Sirsa  2015    July           14.50           27.75   31  25.5  31.8
# 367     Sirsa  2015    June            1.75            6.25   24  26.5  38.2
# 368     Sirsa  2015    June            1.75            6.25   25  27.8  39.3
# 369     Sirsa  2015    June            1.75            6.25   26    27  38.9
#
#       Tavg  RH avg  Pest Count Pest_label
# ...

# %%
final['Pest_label'].value_counts()
# Out:
# low          317
# medium        20
# very high      8
# high           3
# Name: Pest_label, dtype: int64

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x="Year", y="Pest Count", data=final, hue="Pest_label")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Pest Count'>

# %% [markdown]
# # Modelling
# 1) Input parameters = Location, RH avg, Tavg
#
# 2) Change the location into numerical classes

# %%
final['Location'].replace('Faridkot',0,inplace=True)
final['Location'].replace('Sirsa',1,inplace=True)
final['Location'].replace('Hisar',2,inplace=True)

# %%
model=final[['Location','Tavg','RH avg','Pest_label']]

# %%
model.isnull().sum()
# Out:
# Location       0
# Tavg           0
# RH avg         0
# Pest_label    22
# dtype: int64

# %%
model.dropna(inplace=True)
# Out:
# C:\Users\SqyUser.SY-LP-GGN-511\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
X=model.iloc[:,:-1].values

# %%
y=model['Pest_label']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=17)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb=GaussianNB()

# %%
gnb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=gnb.predict(X_test)

# %%
y_pred
# Out:
# array(['low', 'low', 'low', 'very high', 'low', 'medium', 'medium',
#        'very high', 'very high', 'low', 'low', 'low', 'low', 'low',
#        'medium', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'medium', 'low', 'low', 'low', 'medium', 'medium', 'medium',
#        'low', 'low', 'medium', 'low', 'low', 'medium', 'low', 'low',
#        'low', 'low', 'low', 'medium', 'low', 'low', 'very high', 'medium',
#        'medium', 'medium', 'low', 'low', 'very high', 'low', 'low', 'low',
#        'low', 'low', 'low', 'medium', 'low', 'low', 'medium', 'high',
#        'very high', 'low', 'low', 'medium', 'low', 'low', 'low'],
#       dtype='<U9')

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7285714285714285

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[ 0,  0,  0,  0],
#        [ 1, 47, 10,  4],
#        [ 0,  0,  3,  1],
#        [ 0,  0,  3,  1]], dtype=int64)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.00      0.00      0.00         0
#          low       1.00      0.76      0.86        62
#       medium       0.19      0.75      0.30         4
#    very high       0.17      0.25      0.20         4
#
#     accuracy                           0.73        70
#    macro avg       0.34      0.44      0.34        70
# weighted avg       0.91      0.73      0.79        70
# C:\Users\SqyUser.SY-LP-GGN-511\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # NOTE: With the help of classification model, we found the accuracy nearly 73% because of biased data & Because of non-uniform data as shown below.

# %%
model['Pest_label'].value_counts()
# Out:
# low          317
# medium        20
# very high      8
# high           3
# Name: Pest_label, dtype: int64

# %% [markdown]
# # END NOTE!!
